# %%
# Importing pandas, numpy and os libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Katarina M\Documents\Instacart Basket Analysis'

# %% [markdown]
# #### 1.Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
orders_products_merged_up = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_update.pkl'))

# %%
df = orders_products_merged_up[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
# 6    550135        1    prior             7          1                  9
# 7   3108588        1    prior             8          1                 14
# 8   2295261        1    prior             9          1                 16
# 9   2550362        1    prior            10          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                       0         196                  1          0
# ...

# %% [markdown]
# #### 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
orders_products_merged_up.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #### 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# Compared to subset, the entire dataframe gives entire picture of order number from all departments. In other words, picture of POPULATION vs. SAMPLE. The range of 'order_number' mean is also larger (DATA SPREAD).

# %% [markdown]
# #### 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions

# %%
orders_products_merged_up['max_order'] = orders_products_merged_up.groupby(['user_id'])['order_number'].transform(np.max)

# %%
pd.options.display.max_rows = None

# %%
orders_products_merged_up.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# ...

# %% [markdown]
# Creating a flag that assigns a “loyalty” label to a user ID

# %%
orders_products_merged_up.loc[orders_products_merged_up['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
orders_products_merged_up.loc[(orders_products_merged_up['max_order'] <= 40) & (orders_products_merged_up['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
orders_products_merged_up.loc[orders_products_merged_up['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
orders_products_merged_up['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
orders_products_merged_up.shape
# Out:
# (32404859, 22)

# %%
orders_products_merged_up[['user_id', 'loyalty_flag', 'order_number']].head(100)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# #### 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers

# %%
orders_products_merged_up.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# It seems like that the mean prices of the product purchased by loyal customers is the lowest. The highest purchase is from new customers

# %% [markdown]
# #### 6. The team now wants to target different types of spenders in their marketing campaigns.

# %% [markdown]
# This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
#
#     If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
#     If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
orders_products_merged_up['avg_price'] = orders_products_merged_up.groupby(['user_id'])['prices'].transform(np.mean)

# %%
orders_products_merged_up.loc[orders_products_merged_up['avg_price'] < 10, 'spender_flag'] = 'Low spender'

# %%
orders_products_merged_up.loc[orders_products_merged_up['avg_price'] >= 10, 'spender_flag'] = 'High spender'

# %%
orders_products_merged_up['spender_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spender_flag, dtype: int64

# %% [markdown]
# #### 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
#
#     If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
#     If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
#     If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
orders_products_merged_up['median_days_since_prior_order'] =orders_products_merged_up.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
orders_products_merged_up.loc[orders_products_merged_up['median_days_since_prior_order']>20, 'frequency_flag'] = 'Non-frequent customer'

# %%
orders_products_merged_up.loc[(orders_products_merged_up['median_days_since_prior_order']>10) & (orders_products_merged_up['median_days_since_prior_order']<=20), 'frequency_flag'] = 'Regular customer'

# %%
orders_products_merged_up.loc[orders_products_merged_up['median_days_since_prior_order']<=10, 'frequency_flag'] = 'Frequent customer'

# %%
orders_products_merged_up['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        22796659
# Regular customer          6921472
# Non-frequent customer     2686728
# Name: frequency_flag, dtype: int64

# %% [markdown]
# #### 8.  Ensure your notebook is clean and structured and that your code is well commented.

# %% [markdown]
# #### 9.  Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
orders_products_merged_up.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_update2.pkl'))
